# %%
import pickle
from sklearn.decomposition import KernelPCA
import plotly.graph_objects as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from IPython.display import Image
init_notebook_mode(connected=True)
import plotly.io as pio
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import wwlgpr
import sys
import os

# %%
basepath = wwlgpr.__path__

# %%
basepath[0] + "/../supplementary"
# Out:
# '/home/wenbinxu/PhD/Data/Graph/plot/result_VScode/code_github/WWL-GPR/wwlgpr/../supplementary'

# %%
path = basepath[0] + "/../supplementary/README.txt"

# %%
path
# Out:
# '/home/wenbinxu/PhD/Data/Graph/plot/result_VScode/code_github/WWL-GPR/wwlgpr/../supplementary/README.txt'

# %%
with open(path, "r") as infile:
    text = infile.readlines()

# %%
print(text)
# Out:
# ['check-list:\n', '1. simple_adsorbate_db.zip\n', 'include 1422 optimized structures of 8 simple adsorbates on various surfaces and their adsorption energies \n', '\n', '2. complex_adsorbate_db.zip\n', 'include 1878 optimized sturctures of 41 small to complex adosrbates on Cu,Co,Pd,Rh,Pt,CuCo surfaces and their adsorption energies.\n', 'we use 1679 (Cu, Co, Pd, Rh) out of 1878 samples performing interpolation task, remaining 199 samples (Pt, CuCo)for purpose of extrapolation\n']

# %%
ls
# Out:
# complex_adsorbate_db.zip  pre_computed_wwlgpr.pickle  simple_adsorbate_db.zip
# kpca.ipynb                README.txt

# %%
os.path.dirname(basepath[0])
# Out:
# '/home/wenbinxu/PhD/Data/Graph/plot/result_VScode/code_github/WWL-GPR'

# %%
os.path.abspath("README.txt")
# Out:
# '/home/wenbinxu/PhD/Data/Graph/plot/result_VScode/code_github/WWL-GPR/supplementary/README.txt'

# %%
from wwlgpr.Utility import load_base_path

# %%
load_base_path()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-95de9a9f3669> in <module>
# ----> 1 load_base_path()
#
# ~/PhD/Data/Graph/plot/result_VScode/code_github/WWL-GPR/wwlgpr/Utility.py in load_base_path()
#     138
#     139 def load_base_path():
# --> 140     return os.path.dirname(wwlgpr.__path__)
#
# AttributeError: module 'wwlgpr' has no attribute '_path_'

# %%
wwlgpr.__path__
# Out:
# ['/home/wenbinxu/PhD/Data/Graph/plot/result_VScode/code_github/WWL-GPR/wwlgpr']

# %%
with open("pre_computed_wwlgpr.pickle", "rb") as infile:
    pre_computed_kernel = pickle.load(infile)
with open("./../database/puremetal_filenames.pickle", "rb") as infile:
    filenames = pickle.load(infile)
with open("./../database/puremetal_ads_energies.pickle", "rb") as infile:
    ads_energies = pickle.load(infile)

# %%
def plt_kpca(kernel_matrix, y=None, name_list=None):
    kpca = KernelPCA(kernel='precomputed', n_components=2)
    x_kpca = kpca.fit_transform(kernel_matrix)
    colors  = y
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=x_kpca[:,0], y=x_kpca[:,1], mode='markers',hovertext=name_list,
                             marker=dict(
                                 size=10,
                                 #color = "black",
                                 color =colors,
                                 colorscale="Viridis",
                                 colorbar=dict(title="ads_energy")
                                        )
                             
                             ))
    fig.update_layout(     
                            font = dict(
                                        family='Times New Roman',color='black', size=22),
                  
                            plot_bgcolor = 'white',
                            xaxis = dict(
                                        title='PC1',
                                        showline=True,
                                        showgrid=False,
                                        gridcolor="white",
                                        showticklabels=False,
                                        linecolor='black',
                                        linewidth=2,
                                        ticks='outside',
                                        mirror=True,),

                            yaxis = dict(
                                        #title='<b>Bold</b> <i>animals</i>',
                                        title='PC2',
                                        showline=True,
                                        showgrid=False,
                                        gridcolor="white",
                                        showticklabels=False,
                                        linecolor='black',
                                        linewidth=2,
                                        ticks='outside',
                                        mirror=True,)
                         )
    fig.show(renderer="png", width=600, height=600)
    #fig.show()

# %%
plt_kpca(pre_computed_kernel, ads_energies, filenames)
